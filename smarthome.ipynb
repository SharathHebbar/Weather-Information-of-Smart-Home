# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Loading dataframe or dataset

# %%
data = pd.read_csv('C:\\projects\\ml\\0.datasets\\smarthomedatasets\\Home.csv')
data.head()
# Out:
# c:\users\hebbar\appdata\local\programs\python\python39\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (0,27) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 0  1451624400  0.932833  0.003483            0.932833         0.000033
# 1  1451624401  0.934333  0.003467            0.934333         0.000000
# 2  1451624402  0.931817  0.003467            0.931817         0.000017
# 3  1451624403  1.022050  0.003483            1.022050         0.000017
# 4  1451624404  1.139400  0.003467            1.139400         0.000133
#
#    Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  Fridge [kW]  \
# 0        0.020700        0.061917          0.442633     0.124150
# 1        0.020717        0.063817          0.444067     0.124000
# 2        0.020700        0.062317          0.446067     0.123533
# ...

# %%
data
# Out:
#               time  use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 0       1451624400  0.932833  0.003483            0.932833         0.000033
# 1       1451624401  0.934333  0.003467            0.934333         0.000000
# 2       1451624402  0.931817  0.003467            0.931817         0.000017
# 3       1451624403  1.022050  0.003483            1.022050         0.000017
# 4       1451624404  1.139400  0.003467            1.139400         0.000133
# ...            ...       ...       ...                 ...              ...
# 503906  1452128306  1.599333  0.003233            1.599333         0.000050
# 503907  1452128307  1.924267  0.003217            1.924267         0.000033
# 503908  1452128308  1.978200  0.003217            1.978200         0.000050
# 503909  1452128309  1.990950  0.003233            1.990950         0.000050
# 503910           \       NaN       NaN                 NaN              NaN
#
# ...

# %% [markdown]
# ### Data cleansing or preprocessing

# %%
data.shape
# Out:
# (503911, 32)

# %%
data.describe()
# Out:
#             use [kW]       gen [kW]  House overall [kW]  Dishwasher [kW]  \
# count  503910.000000  503910.000000       503910.000000    503910.000000
# mean        0.858962       0.076229            0.858962         0.031368
# std         1.058207       0.128428            1.058207         0.190951
# min         0.000000       0.000000            0.000000         0.000000
# 25%         0.367667       0.003367            0.367667         0.000000
# 50%         0.562333       0.004283            0.562333         0.000017
# 75%         0.970250       0.083917            0.970250         0.000233
# max        14.714567       0.613883           14.714567         1.401767
#
#        Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]    Fridge [kW]  \
# count   503910.000000   503910.000000     503910.000000  503910.000000
# mean         0.099210        0.136779          0.081287       0.063556
# std          0.169059        0.178631          0.104466       0.076199
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503911 entries, 0 to 503910
# Data columns (total 32 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   time                 503911 non-null  object
#  1   use [kW]             503910 non-null  float64
#  2   gen [kW]             503910 non-null  float64
#  3   House overall [kW]   503910 non-null  float64
#  4   Dishwasher [kW]      503910 non-null  float64
#  5   Furnace 1 [kW]       503910 non-null  float64
#  6   Furnace 2 [kW]       503910 non-null  float64
#  7   Home office [kW]     503910 non-null  float64
#  8   Fridge [kW]          503910 non-null  float64
#  9   Wine cellar [kW]     503910 non-null  float64
#  10  Garage door [kW]     503910 non-null  float64
#  11  Kitchen 12 [kW]      503910 non-null  float64
#  12  Kitchen 14 [kW]      503910 non-null  float64
#  13  Kitchen 38 [kW]      503910 non-null  float64
# ...

# %% [markdown]
# #### as we have only one null value rather than filling it we will drop it

# %%
data = data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503910 entries, 0 to 503909
# Data columns (total 32 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   time                 503910 non-null  object
#  1   use [kW]             503910 non-null  float64
#  2   gen [kW]             503910 non-null  float64
#  3   House overall [kW]   503910 non-null  float64
#  4   Dishwasher [kW]      503910 non-null  float64
#  5   Furnace 1 [kW]       503910 non-null  float64
#  6   Furnace 2 [kW]       503910 non-null  float64
#  7   Home office [kW]     503910 non-null  float64
#  8   Fridge [kW]          503910 non-null  float64
#  9   Wine cellar [kW]     503910 non-null  float64
#  10  Garage door [kW]     503910 non-null  float64
#  11  Kitchen 12 [kW]      503910 non-null  float64
#  12  Kitchen 14 [kW]      503910 non-null  float64
#  13  Kitchen 38 [kW]      503910 non-null  float64
# ...

# %% [markdown]
# #### checking the datas of object datatype

# %%
data['icon'].value_counts()
# Out:
# clear-night            194536
# clear-day              182252
# rain                    43081
# partly-cloudy-day       39492
# partly-cloudy-night     27324
# snow                     7550
# cloudy                   6041
# wind                     2660
# fog                       974
# Name: icon, dtype: int64

# %%
data['summary'].value_counts()
# Out:
# Clear                       376730
# Partly Cloudy                62268
# Light Rain                   27368
# Drizzle                      10370
# Overcast                      6041
# Rain                          5169
# Mostly Cloudy                 4548
# Light Snow                    4323
# Flurries                      1789
# Breezy                        1561
# Snow                          1152
# Breezy and Partly Cloudy      1041
# Foggy                          974
# Rain and Breezy                174
# Heavy Snow                     171
# Flurries and Breezy            115
# Breezy and Mostly Cloudy        58
# Dry                             58
# Name: summary, dtype: int64

# %%
data['cloudCover'].value_counts()
# Out:
# 0.0     63596
# 0.31    48101
# 1.0     47255
# 0.03    33186
# 0.04    23711
#         ...
# 0.54       58
# 0.35       58
# 0.17       58
# 0.44       58
# 0.59       57
# Name: cloudCover, Length: 118, dtype: int64

# %%
data['time'].value_counts()
# Out:
# 1451624400    1
# 1451960350    1
# 1451960348    1
# 1451960347    1
# 1451960346    1
#              ..
# 1451792365    1
# 1451792364    1
# 1451792363    1
# 1451792362    1
# 1452128309    1
# Name: time, Length: 503910, dtype: int64

# %% [markdown]
# ### plotting graph

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,6))
plt.plot(data['time'],data['precipProbability'])
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(data['summary'],data['precipProbability'])
plt.xticks(rotation=90,fontsize=15)
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(data['icon'],data['precipProbability'])
plt.xticks(rotation=90,fontsize=15)
plt.show()

# %% [markdown]
# ### I will drop time column as it wont matter much in the dataset

# %%
df = data.drop(['time'],axis = 1)
df.describe()
# Out:
#             use [kW]       gen [kW]  House overall [kW]  Dishwasher [kW]  \
# count  503910.000000  503910.000000       503910.000000    503910.000000
# mean        0.858962       0.076229            0.858962         0.031368
# std         1.058207       0.128428            1.058207         0.190951
# min         0.000000       0.000000            0.000000         0.000000
# 25%         0.367667       0.003367            0.367667         0.000000
# 50%         0.562333       0.004283            0.562333         0.000017
# 75%         0.970250       0.083917            0.970250         0.000233
# max        14.714567       0.613883           14.714567         1.401767
#
#        Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]    Fridge [kW]  \
# count   503910.000000   503910.000000     503910.000000  503910.000000
# mean         0.099210        0.136779          0.081287       0.063556
# std          0.169059        0.178631          0.104466       0.076199
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503910 entries, 0 to 503909
# Data columns (total 31 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   use [kW]             503910 non-null  float64
#  1   gen [kW]             503910 non-null  float64
#  2   House overall [kW]   503910 non-null  float64
#  3   Dishwasher [kW]      503910 non-null  float64
#  4   Furnace 1 [kW]       503910 non-null  float64
#  5   Furnace 2 [kW]       503910 non-null  float64
#  6   Home office [kW]     503910 non-null  float64
#  7   Fridge [kW]          503910 non-null  float64
#  8   Wine cellar [kW]     503910 non-null  float64
#  9   Garage door [kW]     503910 non-null  float64
#  10  Kitchen 12 [kW]      503910 non-null  float64
#  11  Kitchen 14 [kW]      503910 non-null  float64
#  12  Kitchen 38 [kW]      503910 non-null  float64
#  13  Barn [kW]            503910 non-null  float64
# ...

# %% [markdown]
# ### we will label encode means we will convert all the string values into floating values

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
x1 = le.fit_transform(df.icon.values)
x1.shape
# Out:
# (503910,)

# %%
df.icon.value_counts()
# Out:
# clear-night            194536
# clear-day              182252
# rain                    43081
# partly-cloudy-day       39492
# partly-cloudy-night     27324
# snow                     7550
# cloudy                   6041
# wind                     2660
# fog                       974
# Name: icon, dtype: int64

# %%
x1dict = {
    0 : 'clear-night',
    1 : 'clear-day',
    2 : 'rain',
    3 : 'partly-cloudy-day',
    4 : 'partly-cloudy-night',
    5 : 'snow',
    6 : 'cloudy',
    7 : 'wind',
    8 : 'fog'
}

# %%
x2 = le.fit_transform(df.summary .values)
x2
# Out:
# array([ 3,  3,  3, ..., 10, 10, 10])

# %%
df.summary.value_counts()
# Out:
# Clear                       376730
# Partly Cloudy                62268
# Light Rain                   27368
# Drizzle                      10370
# Overcast                      6041
# Rain                          5169
# Mostly Cloudy                 4548
# Light Snow                    4323
# Flurries                      1789
# Breezy                        1561
# Snow                          1152
# Breezy and Partly Cloudy      1041
# Foggy                          974
# Rain and Breezy                174
# Heavy Snow                     171
# Flurries and Breezy            115
# Breezy and Mostly Cloudy        58
# Dry                             58
# Name: summary, dtype: int64

# %%
x2dict = {}

# %%
# f,c=0,0
# for i in df.cloudCover:
#     if type(i) == 'float':
#         f+=1
#     else:
#         c+=1
# f,c

# %%
df.iloc[:,26].values
# Out:
# array(['cloudCover', 'cloudCover', 'cloudCover', ..., 0.31, 0.31, 0.31],
#       dtype=object)

# %% [markdown]
# ### as of now due to mixed values i will drop cloudCover column

# %%
df1 = df.drop(['cloudCover'],axis=1)
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503910 entries, 0 to 503909
# Data columns (total 30 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   use [kW]             503910 non-null  float64
#  1   gen [kW]             503910 non-null  float64
#  2   House overall [kW]   503910 non-null  float64
#  3   Dishwasher [kW]      503910 non-null  float64
#  4   Furnace 1 [kW]       503910 non-null  float64
#  5   Furnace 2 [kW]       503910 non-null  float64
#  6   Home office [kW]     503910 non-null  float64
#  7   Fridge [kW]          503910 non-null  float64
#  8   Wine cellar [kW]     503910 non-null  float64
#  9   Garage door [kW]     503910 non-null  float64
#  10  Kitchen 12 [kW]      503910 non-null  float64
#  11  Kitchen 14 [kW]      503910 non-null  float64
#  12  Kitchen 38 [kW]      503910 non-null  float64
#  13  Barn [kW]            503910 non-null  float64
# ...

# %%
df2 = df1.drop(['summary','icon'],axis = 1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503910 entries, 0 to 503909
# Data columns (total 28 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   use [kW]             503910 non-null  float64
#  1   gen [kW]             503910 non-null  float64
#  2   House overall [kW]   503910 non-null  float64
#  3   Dishwasher [kW]      503910 non-null  float64
#  4   Furnace 1 [kW]       503910 non-null  float64
#  5   Furnace 2 [kW]       503910 non-null  float64
#  6   Home office [kW]     503910 non-null  float64
#  7   Fridge [kW]          503910 non-null  float64
#  8   Wine cellar [kW]     503910 non-null  float64
#  9   Garage door [kW]     503910 non-null  float64
#  10  Kitchen 12 [kW]      503910 non-null  float64
#  11  Kitchen 14 [kW]      503910 non-null  float64
#  12  Kitchen 38 [kW]      503910 non-null  float64
#  13  Barn [kW]            503910 non-null  float64
# ...

# %%
x1 = pd.DataFrame(x1)
x1.columns = ['icon']
x1
# Out:
#         icon
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 503905     6
# 503906     6
# 503907     6
# 503908     6
# 503909     6
#
# [503910 rows x 1 columns]

# %%
x2 = pd.DataFrame(x2)
x2.columns = ['summary']
x2
# Out:
#         summary
# 0             3
# 1             3
# 2             3
# 3             3
# 4             3
# ...         ...
# 503905       10
# 503906       10
# 503907       10
# 503908       10
# 503909       10
#
# [503910 rows x 1 columns]

# %%
df2.insert(27,'summary',x2)
df2
# Out:
#         use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  \
# 0       0.932833  0.003483            0.932833         0.000033
# 1       0.934333  0.003467            0.934333         0.000000
# 2       0.931817  0.003467            0.931817         0.000017
# 3       1.022050  0.003483            1.022050         0.000017
# 4       1.139400  0.003467            1.139400         0.000133
# ...          ...       ...                 ...              ...
# 503905  1.601233  0.003183            1.601233         0.000050
# 503906  1.599333  0.003233            1.599333         0.000050
# 503907  1.924267  0.003217            1.924267         0.000033
# 503908  1.978200  0.003217            1.978200         0.000050
# 503909  1.990950  0.003233            1.990950         0.000050
#
#         Furnace 1 [kW]  Furnace 2 [kW]  Home office [kW]  Fridge [kW]  \
# 0             0.020700        0.061917          0.442633     0.124150
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503910 entries, 0 to 503909
# Data columns (total 29 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   use [kW]             503910 non-null  float64
#  1   gen [kW]             503910 non-null  float64
#  2   House overall [kW]   503910 non-null  float64
#  3   Dishwasher [kW]      503910 non-null  float64
#  4   Furnace 1 [kW]       503910 non-null  float64
#  5   Furnace 2 [kW]       503910 non-null  float64
#  6   Home office [kW]     503910 non-null  float64
#  7   Fridge [kW]          503910 non-null  float64
#  8   Wine cellar [kW]     503910 non-null  float64
#  9   Garage door [kW]     503910 non-null  float64
#  10  Kitchen 12 [kW]      503910 non-null  float64
#  11  Kitchen 14 [kW]      503910 non-null  float64
#  12  Kitchen 38 [kW]      503910 non-null  float64
#  13  Barn [kW]            503910 non-null  float64
# ...

# %%
x1
# Out:
#         icon
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 503905     6
# 503906     6
# 503907     6
# 503908     6
# 503909     6
#
# [503910 rows x 1 columns]

# %%
df2.insert(28,'icon',x1)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 503910 entries, 0 to 503909
# Data columns (total 30 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   use [kW]             503910 non-null  float64
#  1   gen [kW]             503910 non-null  float64
#  2   House overall [kW]   503910 non-null  float64
#  3   Dishwasher [kW]      503910 non-null  float64
#  4   Furnace 1 [kW]       503910 non-null  float64
#  5   Furnace 2 [kW]       503910 non-null  float64
#  6   Home office [kW]     503910 non-null  float64
#  7   Fridge [kW]          503910 non-null  float64
#  8   Wine cellar [kW]     503910 non-null  float64
#  9   Garage door [kW]     503910 non-null  float64
#  10  Kitchen 12 [kW]      503910 non-null  float64
#  11  Kitchen 14 [kW]      503910 non-null  float64
#  12  Kitchen 38 [kW]      503910 non-null  float64
#  13  Barn [kW]            503910 non-null  float64
# ...

# %%
df2.shape
# Out:
# (503910, 30)

# %%
df2.head()
# Out:
#    use [kW]  gen [kW]  House overall [kW]  Dishwasher [kW]  Furnace 1 [kW]  \
# 0  0.932833  0.003483            0.932833         0.000033        0.020700
# 1  0.934333  0.003467            0.934333         0.000000        0.020717
# 2  0.931817  0.003467            0.931817         0.000017        0.020700
# 3  1.022050  0.003483            1.022050         0.000017        0.106900
# 4  1.139400  0.003467            1.139400         0.000133        0.236933
#
#    Furnace 2 [kW]  Home office [kW]  Fridge [kW]  Wine cellar [kW]  \
# 0        0.061917          0.442633     0.124150          0.006983
# 1        0.063817          0.444067     0.124000          0.006983
# 2        0.062317          0.446067     0.123533          0.006983
# 3        0.068517          0.446583     0.123133          0.006983
# 4        0.063983          0.446533     0.122850          0.006850
#
#    Garage door [kW]  ...  visibility  apparentTemperature  pressure  \
# ...

# %%
df2.to_csv('homedataset.csv')
